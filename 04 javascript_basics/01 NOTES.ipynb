# %%
# javascript is a full programming language, meaning unlike HTML 
# or CSS it is supporting things such as arrays, loops, and general logic

# %%
# (typing these into console)

# alert("hello world")
# undefined
# //this is a comment
# undefined
# //Basic data types
# undefined
# 10
# 10
# 20.2
# 20.2
# -13.5
# -13.5
# //javascript unlike some other languages treats them all the same as numbers
# undefined

# //strings
# undefined
# "hello world"
# 'hello world'
# "10"
# '10'

# //booleans
# undefined
# true
# true
# false
# false
# //lowercase true and false
# undefined
# // In Python boolean builtins are capitalized - these are lowercase
# undefined

# // undefined and null
# undefined
# undefined
# undefined
# null
# null
# // they are not the same thing - more info on that later
# undefined
# // to clear console type clear()
# undefined

# 4
# 5-1
# 4
# 5*3
# 15
# 10/2
# 5
# 2/5
# 0.4
# //sometimes other languages wont give you the decimal amaount, javascript does do true division
# undefined
# 5**2
# 25
# 10%2
# 0
# 6%4
# 2
# //mod gives back remainder
# undefined

# //strings
# undefined
# "Django is cool"
# 'Django is cool'
# //string concat
# undefined
# "Django" + " is cool"
# 'Django is cool'
# "javascript".length
# 10
# //there are 10 characters in that string
# undefined
# "x x"
# 'x x'
# //whitespace also counts
# undefined
# alert('new \n line \n third')

# //how to input quotes inside of javascript
# alert("hello \"quotes\" ")
# (output) hello "quotes" 

# alert("hello \"andrew\" ")
# (output) hello "andrew" 
# if you didn't have the backslash for the escape javascript 
# would think that you are trying to escape the string

# //indexing
# "andrew"[0]
# 'a'
# //variables
# undefined
# // var varName = value;
# undefined
# var bankAccountSaintLouis = 100;
# undefined
# // javascript camelCasing
# undefined
# bankAccountSaintLouis
# 100
# var deposit = 50;
# undefined
# var total = bankAccountSaintLouis + deposit;
# undefined
# total
# 150
# var myName="Andrew"; alert(myName)
# undefined
# //Andrew
# undefined
# var greet = "welcome back ";
# undefined
# var newName = "jose";
# undefined
# greet + newName
# 'welcome back jose'
# var myVariable
# undefined
# //undefined is unlike null because undefined is created but nothing is defining it
# undefined
# alert('hello')
# undefined
# var bonus = null
# undefined
# var bonus = null;
# undefined
# //bonus was assigned to null
# undefined

# console.log('this is in the console');
# VM4856:1 this is in the console
# undefined
# prompt("enter something")
# 'entered'
# //like input for python
# undefined

# var age = prompt("enter your age")
# undefined
# age
# '21'
# //will return in string form

# %%
# differences to python so far -

# JS --> PY
# // --> #
# alert --> print
# prompt --> input
# var newName="andrew"; ---> newname="andrew"
# "word".length --> len("hello")
# true --> True
# false --> False

# !!!
# to test if equal in value AND type
# "2" == 2; is true in javascript
# to actually test this add an equals sign 
# "2" === 2; is false
# javascript uses type coercion - trying its best to convert both 
# of the objects to similar datatypes to perform the comparison
# 5 !== "5"; is true
# 5 != "5"; is false

# 0 and 1 can be substitutes for true and false
# true == 1; --> true
# true === 1; --> false

# false == 0; --> true
# false === 0; --> false

# null == undefined; --> true 
# null === undefined; --> false

# Nan == Nan --> false 

# logical operators - allows us to combine multiple comparison operators
# 1===1 --> true
# 2===2 --> true
# the AND operator in javascript uses two ampersand (&) symbols
# 2===2 && 1===1 --> true

# OR operators are written with the pipe operator (|)
# you only need one condition to return true
# 3==="s" || 4===4 --> true

# the NOT operator - checking the oposite of a condition
# !(check if x is NOT equal to y)
# !(1===1) --> false
# !(1===2) --> true

# practice 
# var x = 1;
# var y = 2;

# "2" == y && x === 1; --> true
# x >= 0 || y === "2"; --> true
# !(x !== 1) && y === (1+1); --> true
# y !== "2" && x < 10; --> true

# %%
# Control Flow is a fundamental aspect of any full programming 
# language. It allows us to execute code if a certain situation 
# arises. We use it in combination with logical and comparison 
# operators

# IF statements
# ELSE statements
# ELSE IF statements

# we initiate some condition check that returns a boolean, 
# either true or false

# based off those results we use control flow to execute 
# a specific block of code

# if (condition){
#     //execute some code
# }

###
# JS
# if (2 > 1){
#     alert("true")
# }

# !!! VS python
# if 2 > 1:
#     print("true")
###

# if (2 === 1){
#     alert("true")
# }else{
#     alert("false")
# }
# ---> false 

# if (5 === 3){
#     alert("true")
# }else if(5 === 4 ){
#     alert("true")
# }else{
#     alert("false")
# }
# ---> false

# if (5 === 3){
#     alert("true")
# }else if(25 % 5 === 0 ){
#     alert("true")
# }else{
#     alert("false")
# }
# ---> true 

var hot = false;
var temp = 60;

if (temp>80) {
    console.log("temp is greater than 80")
}
